# %% [markdown]
# # TRIGNUM-300M Metrics Dashboard
# Load your `benchmarks/results/` JSON here to visualize Precision, Recall, F1, and Throughput over time.

# %%
import pandas as pd
# Placeholder: df = pd.read_json('../benchmarks/results/latest.json')
# print(df.describe())
