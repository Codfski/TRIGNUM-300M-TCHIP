# %% [markdown]
# # Hallucination Explorer
# Deep dive into False Negatives (FN) to understand where the Subtractive Filter failed to catch a semantic hallucination during the HaluEval / TruthfulQA benchmark runs.
