# %% [markdown]
# # TRIGNUM-300M Pre-Flight Benchmark
#
# - Import SubtractiveFilter, Evaluator, dataset_connectors
# - Load sample datasets (TruthfulQA, HaluEval)
# - Apply filter & compute TP/FP/FN/TN
# - Visualize confusion matrices and per-dataset metrics

# %%
from trignum_core.subtractive_filter import SubtractiveFilter
from trignum_core.evaluator import Evaluator
from trignum_core.dataset_connectors import load_local_json

print("TRIGNUM-300M pre-flight environment initialized.")
