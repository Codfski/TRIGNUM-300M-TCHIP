# %% [markdown]
# # TRIGNUM-300M: Dataset Integration
#
# Demonstrates how to fetch HuggingFace and local datasets dynamically.

# %% [markdown]
# ## Load Connectors

# %%
from trignum_core.dataset_connectors import fetch_hf_dataset, load_local_json

# %% [markdown]
# ## Fetch HuggingFace Sample

# %%
truthfulqa_samples = fetch_hf_dataset("truthfulqa/truthful_qa", "generation", "validation", limit=50)
print(len(truthfulqa_samples), "samples loaded")

# %% [markdown]
# ## Load Local HaluEval QA

# %%
local_samples = load_local_json("data/halueval/qa_data.json")
print(len(local_samples), "samples loaded locally")
