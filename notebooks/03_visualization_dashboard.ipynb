# %% [markdown]
# # TRIGNUM-300M Visualization Dashboard
#
# Use this notebook to explore illogics detection and metrics visually.

# %% [markdown]
# ## Import Modules

# %%
from trignum_core.visualization import plot_confusion_matrix, display_illogics
from trignum_core.subtractive_filter import SubtractiveFilter

# %% [markdown]
# ## Run Filter & Visualize

# %%
sf = SubtractiveFilter()
sample_text = "All cats are dogs. Water is dry."
result = sf.apply(sample_text)

display_illogics(result)

# %% [markdown]
# ## Plot Confusion Matrix (Placeholder)

# %%
plot_confusion_matrix(tp=2, fp=1, tn=5, fn=0)
